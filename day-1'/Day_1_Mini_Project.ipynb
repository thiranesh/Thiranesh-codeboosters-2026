# %% [markdown]
# <a href="https://colab.research.google.com/github/PRAJEENS2024/prajeen-codeboosters-2026/blob/main/Day_1_Mini_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
print("Libraries imported succcessfully")
# Out:
# Libraries imported succcessfully

# %%
df = pd.read_csv('student_performance.csv')

# %%
print("="*35)
print("STUDENT PERFORMANCE EXPLORER REPORT")
print("="*35)
print("\n[1] DATASET OVERVIEW")
print("-"*35)
print("Total Students:", df.shape[0])
print("Total Columns:", df.shape[1])
print("Departments:", len(df['department'].unique()))
# Out:
# ===================================
# STUDENT PERFORMANCE EXPLORER REPORT
# ===================================
#
# [1] DATASET OVERVIEW
# -----------------------------------
# Total Students: 30
# Total Columns: 13
# Departments: 4

# %%
print("\n[2] DEPARTMENT-WISE STUDENT COUNT")
print("-"*35)
print(df['department'].value_counts())
# Out:
# [2] DEPARTMENT-WISE STUDENT COUNT
# -----------------------------------
# department
# Computer Science    13
# Electronics          6
# Mechanical           6
# Civil                5
# Name: count, dtype: int64

# %%
print("\n[3] SCORE ANALYSIS")
print("-"*35)
print("Highest Math Score:", df['math_score'].max())
print("Lowest Math Score:", df['math_score'].min())
print("Average Math Score:", df['math_score'].mean().round(2))
print("Average Programming Score:", df['programming_score'].mean().round(2))
print("Average Attendance:", df['attendance_percentage'].mean().round(2))
# Out:
# [3] SCORE ANALYSIS
# -----------------------------------
# Highest Math Score: 95
# Lowest Math Score: 56
# Average Math Score: 76.07
# Average Programming Score: 67.6
# Average Attendance: 84.5

# %%
print("\n[4] GENDER-WISE AVERAGE SCORES")
print("-"*35)
df['total_score'] = df['math_score'] + df['science_score'] + df['english_score'] + df['programming_score']
gender_scores = df.groupby('gender')['total_score'].mean().round(2)
print(gender_scores)
# Out:
# [4] GENDER-WISE AVERAGE SCORES
# -----------------------------------
# gender
# Female    310.67
# Male      280.67
# Name: total_score, dtype: float64

# %%
print("\n[5] TOP 5 PERFORMERS")
print("-"*35)
top5 = df.sort_values('total_score', ascending = False).head(5)
for index, row in top5.iterrows():
  print(f" {row['name']:<20} | {row['department']:<18}| Score:{row['total_score']}")
# Out:
# [5] TOP 5 PERFORMERS
# -----------------------------------
#  Ananya Das           | Computer Science  | Score:371
#  Tanvi Mehta          | Computer Science  | Score:367
#  Akanksha Yadav       | Computer Science  | Score:365
#  Arjun Nair           | Computer Science  | Score:356
#  Divya Singh          | Computer Science  | Score:356

# %%
print("\n[6] STUDENTS WITH LOW ATTENDANCE")
print("-"*35)
low_att = df[df['attendance_percentage']<75][['name', 'department', 'attendance_percentage']]
if len(low_att) > 0:
  print(low_att.to_string(index=False))
else:
  print("All Students have atendance above 75%")

print("\n"+"="*60)
print("Report Complete")
print("="*60)
# Out:
# [6] STUDENTS WITH LOW ATTENDANCE
# -----------------------------------
#          name  department  attendance_percentage
#   Meera Joshi Electronics                     72
#  Rahul Mishra  Mechanical                     68
#  Manoj Pandey       Civil                     65
# Harish Pillai Electronics                     74
#  Sanjay Dubey       Civil                     70
# Sunita Pillai       Civil                     73
#
# ============================================================
# Report Complete
# ============================================================
